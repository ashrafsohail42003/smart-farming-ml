# %%
import sys, os
sys.path.append(os.path.abspath("../src"))
import data
df = data.load_and_prepare_ml_data("../data/raw/yield_df.csv")
df.head()
# Out:
# 2026-04-14 23:08:57,415 | INFO | Successfully loaded: ../data/raw/yield_df.csv
# 2026-04-14 23:08:57,416 | INFO | ========== STARTING DEEP INSPECTION ==========
# 2026-04-14 23:08:57,419 | INFO | Feature: [Unnamed: 0] | Type: int64
# 2026-04-14 23:08:57,423 | INFO | Feature: [Area] | Type: object
# 2026-04-14 23:08:57,438 | INFO | Feature: [Item] | Type: object
# 2026-04-14 23:08:57,442 | INFO |   -> Unique Classes: ['Maize', 'Potatoes', 'Rice, paddy', 'Sorghum', 'Soybeans', 'Wheat', 'Cassava', 'Sweet potatoes', 'Plantains and others', 'Yams']
# 2026-04-14 23:08:57,453 | INFO | Feature: [Year] | Type: int64
# 2026-04-14 23:08:57,457 | INFO | Feature: [hg/ha_yield] | Type: int64
# 2026-04-14 23:08:57,460 | INFO | Feature: [average_rain_fall_mm_per_year] | Type: float64
# 2026-04-14 23:08:57,463 | INFO | Feature: [pesticides_tonnes] | Type: float64
# 2026-04-14 23:08:57,465 | WARNING |   -> High Skewness detected (3.49). Consider Log Transformation.
# ...

# %%
import os
os.makedirs("../data/processed", exist_ok=True)
df.to_csv("../data/processed/cleaned_data.csv", index=False)
